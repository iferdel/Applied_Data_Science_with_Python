# %%
import pandas as pd

# %%
df_student ={'Name':['mike','alice','shawn'],'School':['engineering','psychology','data science']}
df_staff ={'Name':['rob','mike','paul'],'Role':['Grader','Auctioneer','Flight attendant']}

# %%
df_student=pd.DataFrame(df_student)

# %%
df_staff=pd.DataFrame(df_staff)

# %%
df_student=df_student.set_index('Name')

# %%
df_staff=df_staff.set_index('Name')

# %%
df=pd.merge(df_student,df_staff, how='left', left_index=True, right_index=True)

# %%
df.groupby('')

# %%
import pandas as pd
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'], index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'], columns = ['Grades'])
my_categories = pd.CategoricalDtype(categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'], ordered=True)
grades = df['Grades'].astype(my_categories)
result = grades[(grades>'B') & (grades<'A')]

# %%
result
# Out:
# excellent    A-
# good         B+
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
import pandas as pd
(pd.Timestamp('11/29/2019') + pd.offsets.MonthEnd()).weekday()
# Out:
# 5

# %%
import pandas as pd
pd.Period('01/12/2019', 'M') + 5
# Out:
# Period('2019-06', 'M')

# %%
import pandas as pd
import numpy as np

# Filter all warnings. If you would like to see the warnings, please comment the two lines below.
import warnings
warnings.filterwarnings('ignore')
energy = pd.read_excel('assets/Energy Indicators.xls', header=8, skipfooter=38)

# %%
energy
# Out:
#      Unnamed: 0                 Unnamed: 1                 Unnamed: 2  \
# 0           NaN                        NaN                    Country
# 1           NaN                        NaN                        NaN
# 2           NaN                        NaN                    Andorra
# 3           NaN                        NaN                        NaN
# 4           NaN                        NaN                        NaN
# ..          ...                        ...                        ...
# 231         NaN                   Viet Nam                   Viet Nam
# 232         NaN  Wallis and Futuna Islands  Wallis and Futuna Islands
# 233         NaN                      Yemen                      Yemen
# 234         NaN                     Zambia                     Zambia
# 235         NaN                   Zimbabwe                   Zimbabwe
#
#         Unnamed: 3                Unnamed: 4  \
# 0    Energy Supply  Energy Supply per capita
# ...
